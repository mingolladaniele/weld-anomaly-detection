# %% [markdown]
# ## CREAZIONE DEL DATASET PANDAS A PARTIRE DAI JSON

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import seaborn as sns
from tqdm import tqdm
import statsmodels.tsa.stattools as smt
from collections import Counter
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
# lista di tutti i file json

json_path_list = pathlib.Path('../data/original/').glob('**/*.json')

# %%
# contiene tupla con i soli dati necessari estratti dai json

rows_list = []
for i in tqdm(json_path_list):
    with open(i, 'r') as f:
        data = json.load(f)
    rows_list.append((data['TimeStamp'],
                      data['Message']['WeldLog']['spotName'],
                      data['Message']['WeldLog']['CurrentCurve'],
                      data['Message']['WeldLog']['VoltageCurve']))
# Out:
# 222867it [26:46, 138.76it/s]

# %%
# da lista di tuple a dataset pandas
dataset = pd.DataFrame.from_records(
    rows_list, columns=['TimeStamp', 'spotName', 'CurrentCurve', 'VoltageCurve'])
dataset
# Out:
#                   TimeStamp    spotName  \
# 0       2019-09-17T17:33:48  60061_0_00
# 1       2019-11-07T12:29:01  60090_0_00
# 2       2019-11-07T12:29:01  60092_0_00
# 3       2019-11-07T12:29:01  60094_0_00
# 4       2019-11-07T12:29:01  60096_0_00
# ...                     ...         ...
# 222862  2020-05-28T15:00:04  60021_0_00
# 222863  2020-05-28T15:00:17  60023_0_00
# 222864  2020-05-28T15:00:17  60025_0_00
# 222865  2020-05-28T15:00:17  60027_0_00
# 222866  2020-05-28T15:00:44
#
#                                              CurrentCurve  \
# 0       [312, 2067, 3862, 5267, 6398, 7217, 7959, 8700...
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 222862  [317, 2095, 3809, 4984, 5714, 6222, 6698, 7110...
# 222863  [317, 2065, 3781, 4926, 5688, 6229, 6801, 7118...
# 222864  [344, 2225, 4011, 5234, 6017, 6613, 7051, 7365...
# 222865  [303, 2034, 3644, 4767, 5526, 6103, 6437, 6680...
# 222866  [339, 2926, 5598, 7380, 8567, 9585, 10349, 105...
#
#                                              VoltageCurve
# 0       [134, 756, 1292, 1623, 1812, 1876, 1946, 2010,...
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 222862  [138, 777, 1332, 1675, 1888, 2008, 2100, 2193,...
# 222863  [139, 769, 1303, 1652, 1853, 1976, 2107, 2142,...
# 222864  [134, 763, 1284, 1602, 1779, 1863, 1946, 1972,...
# 222865  [136, 744, 1264, 1600, 1784, 1904, 1944, 1960,...
# 222866  [125, 906, 1533, 1798, 1857, 1879, 1828, 1644,...
#
# [222867 rows x 4 columns]

# %%
# salvo in pickle per evitare di ripetere le procedure sopra
dataset.to_pickle('../data/original/raw_dataset.pkl')

# %% [markdown]
# ## STATISTICHE DESCRITTIVE

# %%
dataset = pd.read_pickle("../data/original/raw_dataset.pkl")
dataset['TimeStamp'] = pd.to_datetime(dataset['TimeStamp'])
# consideriamo le saldature senza nome come fossero appertenenti al medesimo punto di saldatura (non lo sappiamo se è uno spotname o più a essere senza nome)
dataset['spotName'].replace('', '9999_9_99', inplace=True)
dataset.sort_values('TimeStamp', inplace=True)
print(dataset.dtypes)
dataset
# Out:
# TimeStamp       datetime64[ns]
# spotName                object
# CurrentCurve            object
# VoltageCurve            object
# dtype: object
#                  TimeStamp    spotName  \
# 0      2019-09-17 17:33:48  60061_0_00
# 75852  2019-09-17 17:33:48  60075_0_00
# 75853  2019-09-17 17:33:48  60141_0_00
# 75854  2019-09-17 17:33:48  60163_0_00
# 75855  2019-09-17 17:33:48  60161_0_00
# ...                    ...         ...
# 222858 2020-05-28 15:00:04  60017_0_00
# 222864 2020-05-28 15:00:17  60025_0_00
# 222865 2020-05-28 15:00:17  60027_0_00
# 222863 2020-05-28 15:00:17  60023_0_00
# 222866 2020-05-28 15:00:44   9999_9_99
#
#                                              CurrentCurve  \
# 0       [312, 2067, 3862, 5267, 6398, 7217, 7959, 8700...
# 75852   [322, 2099, 3940, 5296, 6362, 7169, 7589, 7750...
# 75853   [214, 1995, 3836, 5125, 6107, 6813, 7182, 7427...
# 75854   [323, 2137, 4047, 5472, 6475, 7090, 7544, 7803...
# 75855   [327, 2161, 4126, 5468, 6483, 7237, 7662, 7793...
# ...                                                   ...
# 222858                                               None
# 222864  [344, 2225, 4011, 5234, 6017, 6613, 7051, 7365...
# 222865  [303, 2034, 3644, 4767, 5526, 6103, 6437, 6680...
# 222863  [317, 2065, 3781, 4926, 5688, 6229, 6801, 7118...
# 222866  [339, 2926, 5598, 7380, 8567, 9585, 10349, 105...
#
#                                              VoltageCurve
# 0       [134, 756, 1292, 1623, 1812, 1876, 1946, 2010,...
# 75852   [135, 749, 1256, 1534, 1698, 1777, 1748, 1648,...
# 75853   [95, 696, 1217, 1495, 1686, 1759, 1723, 1686, ...
# 75854   [139, 767, 1298, 1598, 1745, 1766, 1779, 1724,...
# 75855   [135, 763, 1263, 1534, 1677, 1748, 1705, 1627,...
# ...                                                   ...
# 222858                                               None
# 222864  [134, 763, 1284, 1602, 1779, 1863, 1946, 1972,...
# 222865  [136, 744, 1264, 1600, 1784, 1904, 1944, 1960,...
# 222863  [139, 769, 1303, 1652, 1853, 1976, 2107, 2142,...
# 222866  [125, 906, 1533, 1798, 1857, 1879, 1828, 1644,...
#
# [222867 rows x 4 columns]

# %%
def plot_custom(dataset, kind, title, xlabel, ylabel, plot_size=(8, 6), tick_size=10):
    ax = dataset.plot(kind=kind, figsize=plot_size, fontsize=tick_size)
    ax.set_title(title, fontsize=20)
    ax.set_ylabel(xlabel, fontsize=17)
    ax.set_xlabel(ylabel, fontsize=17)
    plt.show()

# %%
# 20% di misurazioni mancanti, se manca una colonna manca anche l'altra
null_per_features = dataset.isna().sum()/dataset.shape[0] * 100
plot_custom(null_per_features, 'barh',
            'Count Null per feature', '% Null', 'Feature')

# %% [markdown]
# O le due colonne sono presenti contemporaneamente, o entrambe mancano.

# %%
dataset[(dataset.VoltageCurve.isna()) & ~(dataset.CurrentCurve.isna())]
# Out:
# Empty DataFrame
# Columns: [TimeStamp, spotName, CurrentCurve, VoltageCurve]
# Index: []

# %% [markdown]
# Le misurazioni mancanti non sono solo denotate da Nan ma anche da [-1] e [0].

# %%
dataset[dataset.apply(lambda row: row['CurrentCurve'] ==
                      [-1] or row['CurrentCurve'] == [0], axis=1)]
# Out:
#                  TimeStamp    spotName CurrentCurve VoltageCurve
# 80242  2019-09-26 09:33:14  60026_0_00          [0]          [0]
# 80241  2019-09-26 09:33:14  60184_0_00          [0]          [0]
# 80240  2019-09-26 09:33:14  60166_0_00          [0]          [0]
# 80235  2019-09-26 09:33:14  60088_0_00          [0]          [0]
# 80238  2019-09-26 09:33:14  60032_0_00          [0]          [0]
# ...                    ...         ...          ...          ...
# 222816 2020-05-28 14:52:26  60180_0_00         [-1]         [-1]
# 222817 2020-05-28 14:52:26  60168_0_00         [-1]         [-1]
# 222853 2020-05-28 14:59:45  60167_0_00         [-1]         [-1]
# 222854 2020-05-28 14:59:45  60181_0_00         [-1]         [-1]
# 222855 2020-05-28 14:59:45  60029_0_00         [-1]         [-1]
#
# [35669 rows x 4 columns]

# %%
# sostituiamo i [-1] e [0] con None
dataset.loc[dataset.apply(lambda row:row['CurrentCurve'] ==
                          [-1] or row['CurrentCurve'] == [0], axis=1), ['CurrentCurve', 'VoltageCurve']] = None
null_per_features = dataset.isna().sum()/dataset.shape[0] * 100

# %%
# le percentuali di Nan per feature aumentano rispetto a prima
plot_custom(null_per_features, 'barh',
            'Contiamo i NAN dopo sostituzione dei [-1] e dei [0]', '% Null', 'Feature')

# %%
null_per_spot = dataset.CurrentCurve.isnull().groupby(
    [dataset['spotName']]).sum().astype(int)

plot_custom(null_per_spot, 'bar', 'Misurazioni corrente/tensione mancanti per spot',
            '# Null', 'SpotName', plot_size=(20, 10), tick_size=15)

# %% [markdown]
# Contiamo i null nella colonna CurrentCurve per ogni SPOTNAME (IN TOTALE) considerando i soli timestamp di cui abbiamo le misurazioni.

# %%
def check_na_misurazioni(dataset, column):
    # conterrà una lista di tuple (nome spot, num. null) -> null è None o -1
    spot_current_null = []
    for name in tqdm(dataset.spotName.unique()):
        # non considero gli spot senza misurazioni
        temp = dataset[(dataset.spotName == name) & ~(
            dataset.CurrentCurve.isna())][['spotName', column]]
        count_nan = 0
        for values in temp.iterrows():
            # conto i nan per ogni spotname
            count_nan += sum([1 for val in values[1][1] if val in (None, -1)])
            spot_current_null.append((name, count_nan))
    return pd.DataFrame.from_records(spot_current_null, columns=['spotName', f'Nan_{column}'],
                                     index='spotName')

# %%
nan_spot_currentcurve = check_na_misurazioni(dataset, 'CurrentCurve')

# currentcurve non contiene né None né -1 -> I nan sono 0 per ogni spotname
(nan_spot_currentcurve['Nan_CurrentCurve'] == 0).all()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 77/77 [00:18<00:00,  4.25it/s]
# True

# %%
nan_spot_voltagecurve = check_na_misurazioni(dataset, 'VoltageCurve')

# voltagecurve non contiene né None né -1
(nan_spot_voltagecurve['Nan_VoltageCurve'] == 0).all()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 77/77 [00:11<00:00,  6.61it/s]
# True

# %%
err_current = 0
err_voltage = 0

# verifichiamo che ogni misurazione non contenga typo ma solo numeri
for row in dataset[~dataset.CurrentCurve.isna()][['CurrentCurve', 'VoltageCurve']].iterrows():
    err_current += sum([1 for value in row[1].CurrentCurve if not isinstance(value, int)])
    err_voltage += sum([1 for value in row[1].VoltageCurve if not isinstance(value, int)])
print(
    f"# di valori non numerici in CurrentCurve = {err_current}\n# di valori non numerici in VoltageCurve = {err_voltage}")
# Out:
# # di valori non numerici in CurrentCurve = 0
# # di valori non numerici in VoltageCurve = 0

# %%
# drop dei nan
dataset.dropna(inplace=True)

# %% [markdown]
# Notiamo come i punti di saldatura differiscono nel numero di saldature.<br />
# Il numero di saldature per punto va da un minimo di 724 a un max di 2925.

# %%
welding_spots = dataset.groupby('spotName')['TimeStamp']
welding_spots.nunique().describe()
# Out:
# count      77.000000
# mean     1843.779221
# std       207.108580
# min       532.000000
# 25%      1762.000000
# 50%      1842.000000
# 75%      1901.000000
# max      2298.000000
# Name: TimeStamp, dtype: float64

# %% [markdown]
# Calcoliamo durata media in MS di ogni saldatura per spotName.<br/>
# Durata media saldatura per spotName = (MS_TOTALI_SALDATURA) / (N. DI SALDATURE X SPOT)

# %%
# se non abbiamo la misurazione non lo contiamo
spot_average_ms = []
for name in tqdm(dataset.spotName.unique()):
    count_ms_totali = 0
    lista_saldature_spot = dataset[(dataset.spotName == name) &
                                   ~(dataset.CurrentCurve.isna())]['CurrentCurve'].to_list()
    # sommiamo iterativamente la lunghezza di ogni saldatura x spot
    for saldatura in lista_saldature_spot:
        # lunghezza singola saldatura -> 1 step = 1ms
        count_ms_totali += len(saldatura)
    # len(lista_saldature_spot) corrisponde al # totale di saldature per spot
    spot_average_ms.append((name, count_ms_totali/len(lista_saldature_spot)))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 77/77 [00:01<00:00, 45.11it/s]

# %%
dataset_spot_average_ms = pd.DataFrame.from_records(spot_average_ms, columns=['spotName', 'Average_MS_CurrentCurve'],
                                                    index='spotName')
dataset_spot_average_ms
# Out:
#             Average_MS_CurrentCurve
# spotName
# 60061_0_00               410.728155
# 60075_0_00               411.172140
# 60141_0_00               400.000000
# 60163_0_00               411.200000
# 60161_0_00               408.565733
# ...                             ...
# 60180_0_00               415.897611
# 60047_0_00               409.529281
# 60044_0_00               415.940068
# 60043_0_00               407.261473
# 9999_9_99                100.000000
#
# [77 rows x 1 columns]

# %%
# notiamo come la durata media vari in base allo spot ed

plot_custom(dataset_spot_average_ms, 'bar', 'Durata media in MS di ogni saldatura (CurrentCurve) per SPOT',
            'Millisecondi', 'SpotName', plot_size=(20, 10), tick_size=15)

# %%
spot_average_ms = []
for name in tqdm(dataset.spotName.unique()):
    count_ms_totali = 0
    lista_saldature_spot = dataset[(dataset.spotName == name) &
                                   ~(dataset.VoltageCurve.isna())]['VoltageCurve'].to_list()
    # sommiamo iterativamente la lunghezza di ogni saldatura x spot
    for saldatura in lista_saldature_spot:
        # lunghezza singola saldatura -> 1 step = 1ms
        count_ms_totali += len(saldatura)
    # len(lista_saldature_spot) corrisponde al # totale di saldature per spot
    spot_average_ms.append((name, count_ms_totali/len(lista_saldature_spot)))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 77/77 [00:01<00:00, 44.13it/s]

# %%
# durata media saldatura x spot in millisecondi (MS)
dataset_spot_average_ms = pd.DataFrame.from_records(spot_average_ms, columns=['spotName', 'Average_MS_VoltageCurve'],
                                                    index='spotName')
dataset_spot_average_ms
# Out:
#             Average_MS_VoltageCurve
# spotName
# 60061_0_00               410.728155
# 60075_0_00               411.172140
# 60141_0_00               400.000000
# 60163_0_00               411.200000
# 60161_0_00               408.565733
# ...                             ...
# 60180_0_00               415.897611
# 60047_0_00               409.529281
# 60044_0_00               415.940068
# 60043_0_00               407.261473
# 9999_9_99                100.000000
#
# [77 rows x 1 columns]

# %% [markdown]
# La lunghezza media delle saldature x spot della colonna VoltageCurve è identica a quella della colonna CurrentCurve.<br/>
# Possiamo ipotizzare dunque che nello stesso ms, non ci siano stati problemi nell'acquisire entrambe le misure. Ricordo che abbiamo già accertato che nessuna saldatura ha None o typo al suo interno. <br/>
# Si suppone dunque che il sistema di acquisizione dati apparentemente funzioni.

# %%
# Sapere che le liste in voltagecurve e currentcurve hanno la stessa dimensione ci permette di
# evitare di avere problemi nel momento in cui esplodiamo tale lista (creando timestamp di 1 ms di differenza)

plot_custom(dataset_spot_average_ms, 'bar', 'Durata media in MS di ogni saldatura (VoltageCurve) per SPOT',
            'Millisecondi', 'SpotName', plot_size=(20, 10), tick_size=15)

# %% [markdown]
# # Creazione del sample che verrà utilizzato in fase di testing

# %%
list_all_spotname = dataset.spotName.to_list()
c = Counter(list_all_spotname)
list_global_proportion = [
    (i, c[i] / len(list_all_spotname) * 100.0) for i in c]
list_global_proportion
# Out:
# [('60061_0_00', 1.3037607943517764),
#  ('60075_0_00', 1.3276701077325532),
#  ('60141_0_00', 1.4880031504036455),
#  ('60163_0_00', 1.3255604624342494),
#  ('60161_0_00', 1.3051672245506456),
#  ('60091_0_00', 1.3255604624342494),
#  ('60093_0_00', 1.3220443869370764),
#  ('60095_0_00', 1.29672864335743),
#  ('60077_0_00', 1.2320328542094456),
#  ('60097_0_00', 1.2756321903743917),
#  ('60103_0_00', 1.280554696070434),
#  ('60119_0_00', 1.2742257601755225),
#  ('60115_0_00', 1.2826643413687377),
#  ('60113_0_00', 1.2735225450760879),
#  ('60089_0_00', 1.311496160445557),
#  ('60167_0_00', 1.3037607943517764),
#  ('60031_0_00', 1.338921549323507),
#  ('60029_0_00', 1.4022109082726224),
#  ('60027_0_00', 1.4134623498635763),
#  ('60025_0_00', 1.512615678883857),
#  ('60033_0_00', 1.3375151191246377),
#  ('60021_0_00', 1.6209108041967877),
#  ('60023_0_00', 1.5280864110714185),
#  ('60011_0_00', 1.2355489297066187),
#  ('60001_0_00', 1.3037607943517764),
#  ('60118_0_00', 1.3325926134285955),
#  ('60169_0_00', 1.2925093527608225),
#  ('60090_0_00', 1.3543922815110685),
#  ('60092_0_00', 1.3733790891958033),
#  ('60096_0_00', 1.3431408399201148),
#  ('60102_0_00', 1.3234508171359456),
#  ('60088_0_00', 1.3726758740963687),
#  ('60028_0_00', 1.445107029338134),
#  ('60016_0_00', 1.2812579111698685),
#  ('60074_0_00', 1.3269668926331186),
#  ('60060_0_00', 1.2235942730162301),
#  ('60042_0_00', 1.2686000393800456),
#  ('60020_0_00', 1.143427751680684),
#  ('60026_0_00', 1.381114455289584),
#  ('60140_0_00', 1.4282298669517033),
#  ('60162_0_00', 1.2060138955303648),
#  ('60002_0_00', 1.1743692160558072),
#  ('60185_0_00', 1.3220443869370764),
#  ('60181_0_00', 1.2939157829596917),
#  ('60003_0_00', 1.1462406120784225),
#  ('60017_0_00', 1.2847739866670416),
#  ('60030_0_00', 1.374082304295238),
#  ('60112_0_00', 1.307980084948384),
#  ('60046_0_00', 1.2854772017664762),
#  ('60050_0_00', 1.167337065061461),
#  ('60054_0_00', 1.1898399482433688),
#  ('60058_0_00', 1.2292199938117072),
#  ('60052_0_00', 1.2116396163258416),
#  ('60168_0_00', 1.2390650052037917),
#  ('60022_0_00', 1.5632471660431493),
#  ('60024_0_00', 1.512615678883857),
#  ('60160_0_00', 1.1462406120784225),
#  ('60000_0_00', 1.5984079210148798),
#  ('60053_0_00', 1.2425810807009647),
#  ('60055_0_00', 1.277038620573261),
#  ('60094_0_00', 1.3691597985991955),
#  ('60114_0_00', 1.3410311946218108),
#  ('60032_0_00', 1.3368119040252031),
#  ('60010_0_00', 1.304464009451211),
#  ('60076_0_00', 1.2728193299766533),
#  ('60184_0_00', 1.1497566875755956),
#  ('60166_0_00', 1.234845714607184),
#  ('60051_0_00', 1.2671936091811764),
#  ('60048_0_00', 1.1863238727461958),
#  ('60059_0_00', 1.274928975274957),
#  ('60045_0_00', 1.2953222131585609),
#  ('60049_0_00', 1.2622711034851342),
#  ('60180_0_00', 1.2362521448060533),
#  ('60047_0_00', 1.260864673286265),
#  ('60044_0_00', 1.2320328542094456),
#  ('60043_0_00', 1.3178250963404687),
#  ('9999_9_99', 0.3741104328992152)]

# %%
# percentuale dimensione campione rispetto alla dimensione della popolazione
sample_percentage_population = 0.01
sample = dataset.groupby('spotName', group_keys=False).apply(
    lambda x: x.sample(frac=sample_percentage_population, random_state = RANDOM_SEED))
list_sample_spotname = sample.spotName.to_list()
c = Counter(list_sample_spotname)
list_sample_proportion = [
    (i, c[i] / len(list_sample_spotname) * 100.0) for i in c]
list_sample_proportion

# Le percentuali sono uguali, quindi il nostro campione segue le stesse proporzioni presenti nella popolazione
# Out:
# [('60000_0_00', 1.6129032258064515),
#  ('60001_0_00', 1.332398316970547),
#  ('60002_0_00', 1.1921458625525947),
#  ('60003_0_00', 1.1220196353436185),
#  ('60010_0_00', 1.332398316970547),
#  ('60011_0_00', 1.262272089761571),
#  ('60016_0_00', 1.262272089761571),
#  ('60017_0_00', 1.262272089761571),
#  ('60020_0_00', 1.1220196353436185),
#  ('60021_0_00', 1.6129032258064515),
#  ('60022_0_00', 1.5427769985974753),
#  ('60023_0_00', 1.5427769985974753),
#  ('60024_0_00', 1.5427769985974753),
#  ('60025_0_00', 1.5427769985974753),
#  ('60026_0_00', 1.402524544179523),
#  ('60027_0_00', 1.402524544179523),
#  ('60028_0_00', 1.4726507713884993),
#  ('60029_0_00', 1.402524544179523),
#  ('60030_0_00', 1.402524544179523),
#  ('60031_0_00', 1.332398316970547),
#  ('60032_0_00', 1.332398316970547),
#  ('60033_0_00', 1.332398316970547),
#  ('60042_0_00', 1.262272089761571),
#  ('60043_0_00', 1.332398316970547),
#  ('60044_0_00', 1.262272089761571),
#  ('60045_0_00', 1.262272089761571),
#  ('60046_0_00', 1.262272089761571),
#  ('60047_0_00', 1.262272089761571),
#  ('60048_0_00', 1.1921458625525947),
#  ('60049_0_00', 1.262272089761571),
#  ('60050_0_00', 1.1921458625525947),
#  ('60051_0_00', 1.262272089761571),
#  ('60052_0_00', 1.1921458625525947),
#  ('60053_0_00', 1.262272089761571),
#  ('60054_0_00', 1.1921458625525947),
#  ('60055_0_00', 1.262272089761571),
#  ('60058_0_00', 1.1921458625525947),
#  ('60059_0_00', 1.262272089761571),
#  ('60060_0_00', 1.1921458625525947),
#  ('60061_0_00', 1.332398316970547),
#  ('60074_0_00', 1.332398316970547),
#  ('60075_0_00', 1.332398316970547),
#  ('60076_0_00', 1.262272089761571),
#  ('60077_0_00', 1.262272089761571),
#  ('60088_0_00', 1.402524544179523),
#  ('60089_0_00', 1.332398316970547),
#  ('60090_0_00', 1.332398316970547),
#  ('60091_0_00', 1.332398316970547),
#  ('60092_0_00', 1.402524544179523),
#  ('60093_0_00', 1.332398316970547),
#  ('60094_0_00', 1.332398316970547),
#  ('60095_0_00', 1.262272089761571),
#  ('60096_0_00', 1.332398316970547),
#  ('60097_0_00', 1.262272089761571),
#  ('60102_0_00', 1.332398316970547),
#  ('60103_0_00', 1.262272089761571),
#  ('60112_0_00', 1.332398316970547),
#  ('60113_0_00', 1.262272089761571),
#  ('60114_0_00', 1.332398316970547),
#  ('60115_0_00', 1.262272089761571),
#  ('60118_0_00', 1.332398316970547),
#  ('60119_0_00', 1.262272089761571),
#  ('60140_0_00', 1.402524544179523),
#  ('60141_0_00', 1.4726507713884993),
#  ('60160_0_00', 1.1220196353436185),
#  ('60161_0_00', 1.332398316970547),
#  ('60162_0_00', 1.1921458625525947),
#  ('60163_0_00', 1.332398316970547),
#  ('60166_0_00', 1.262272089761571),
#  ('60167_0_00', 1.332398316970547),
#  ('60168_0_00', 1.262272089761571),
#  ('60169_0_00', 1.262272089761571),
#  ('60180_0_00', 1.262272089761571),
#  ('60181_0_00', 1.262272089761571),
#  ('60184_0_00', 1.1220196353436185),
#  ('60185_0_00', 1.332398316970547),
#  ('9999_9_99', 0.3506311360448808)]

# %% [markdown]
# # CurrentCurve e VoltageCurve forniscono la stessa informazione?

# %%
# VISUALIZZAZIONE GRAFICA CCF -- CURRENTCURVE VS VOLTAGECURVE
# per ogni misurazione giornaliera restituisco in output la CCF minore con lag 10 -> rimanere sempre alta
ccf_to_show = 10
n_lag = 10
for i, (index_DF, row) in enumerate(sample.iterrows()):
    if i == ccf_to_show:
        break
    cc = np.array(row['CurrentCurve'], dtype='float')
    vc = np.array(row['VoltageCurve'], dtype='float')
    ccf = plt.xcorr(cc, vc, usevlines=True, maxlags=n_lag)
    plt.title(
        f"GIORNALIERA N. {i} -- SPOTNAME N: {row['spotName']} -- CROSS-CORR CURRENT vs VOLTAGE")
    plt.xlabel("LAG", fontsize=12)
    plt.ylabel("CCF", fontsize=12)
    plt.show()

# %% [markdown]
# Notiamo come il valore minimo di cross-correlation tra la curva CurrentCurve e la curva VoltageCurve per ogni spotname, impostando 10 come valore di lag da analizzare di default, sia sempre alto.<br/>
# Inoltre le due feature sono legate da un rapporto di dipendenza descritto dalla legge di Ohm: $V=I \times R$<br/>
# Per alleggerire il carico computazionale decidiamo di non considerare la colonna VoltageCurve.

# %%
# per ogni misurazione giornaliera restituisco in output la CCF minore con lag 10 -> rimanere sempre alta
print("CROSS-CORRELATION CURRENT VS VOLTAGE -- MISURAZIONI GIORNALIERE\n")
for i, (index, row) in enumerate(sample.iterrows()):
    cc = np.array(row['CurrentCurve'], dtype='float')
    vc = np.array(row['VoltageCurve'], dtype='float')
    ccf = plt.xcorr(cc, vc, usevlines=True, maxlags=n_lag)[1]
    plt.clf()
    print(f"TOT. GIORNALIERA N. {i} -- SPOTNAME N: {row['spotName']} -- MIN. CCF: {min(ccf)}")
# Out:
# CROSS-CORRELATION CURRENT VS VOLTAGE -- MISURAZIONI GIORNALIERE
#
# TOT. GIORNALIERA N. 0 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9604590451611745
# TOT. GIORNALIERA N. 1 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9551967423077315
# TOT. GIORNALIERA N. 2 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9623489604007216
# TOT. GIORNALIERA N. 3 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9620476876412206
# TOT. GIORNALIERA N. 4 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.960995917061052
# TOT. GIORNALIERA N. 5 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9613443968594135
# TOT. GIORNALIERA N. 6 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9628853827958379
# TOT. GIORNALIERA N. 7 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9619144150023117
# TOT. GIORNALIERA N. 8 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9600352073497865
# TOT. GIORNALIERA N. 9 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.963506402783905
# TOT. GIORNALIERA N. 10 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9628848494913119
# TOT. GIORNALIERA N. 11 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9500754416701265
# TOT. GIORNALIERA N. 12 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9610354473573199
# TOT. GIORNALIERA N. 13 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9567593481394544
# TOT. GIORNALIERA N. 14 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9486056987423402
# TOT. GIORNALIERA N. 15 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9605741595785177
# TOT. GIORNALIERA N. 16 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9628723544929171
# TOT. GIORNALIERA N. 17 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9617988794482678
# TOT. GIORNALIERA N. 18 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.961785736884055
# TOT. GIORNALIERA N. 19 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9617355131073649
# TOT. GIORNALIERA N. 20 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9624618326981672
# TOT. GIORNALIERA N. 21 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9613826039942387
# TOT. GIORNALIERA N. 22 -- SPOTNAME N: 60000_0_00 -- MIN. CCF: 0.9627531205559494
# TOT. GIORNALIERA N. 23 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9683050554188937
# TOT. GIORNALIERA N. 24 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9689822458043622
# TOT. GIORNALIERA N. 25 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9664752095695324
# TOT. GIORNALIERA N. 26 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.965517139976643
# TOT. GIORNALIERA N. 27 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9685273779143244
# TOT. GIORNALIERA N. 28 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9668285829582581
# TOT. GIORNALIERA N. 29 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9610350157339753
# TOT. GIORNALIERA N. 30 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9609254178924639
# TOT. GIORNALIERA N. 31 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9683333124677969
# TOT. GIORNALIERA N. 32 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9667741039735404
# TOT. GIORNALIERA N. 33 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9658659492707844
# TOT. GIORNALIERA N. 34 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9666706497637275
# TOT. GIORNALIERA N. 35 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9632039313883982
# TOT. GIORNALIERA N. 36 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9608919847330335
# TOT. GIORNALIERA N. 37 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9689554231453463
# TOT. GIORNALIERA N. 38 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9666549717457835
# TOT. GIORNALIERA N. 39 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9677153912126774
# TOT. GIORNALIERA N. 40 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.9703927512271882
# TOT. GIORNALIERA N. 41 -- SPOTNAME N: 60001_0_00 -- MIN. CCF: 0.967888423290759
# TOT. GIORNALIERA N. 42 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9554263611233432
# TOT. GIORNALIERA N. 43 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9570380924014585
# TOT. GIORNALIERA N. 44 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9643094407533637
# TOT. GIORNALIERA N. 45 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.963598323643379
# TOT. GIORNALIERA N. 46 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9527651722817148
# TOT. GIORNALIERA N. 47 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9645161419958052
# TOT. GIORNALIERA N. 48 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9635853312203121
# TOT. GIORNALIERA N. 49 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9634767142132106
# TOT. GIORNALIERA N. 50 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9637255431597526
# TOT. GIORNALIERA N. 51 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9650699358903432
# TOT. GIORNALIERA N. 52 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9643694639943757
# TOT. GIORNALIERA N. 53 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9647910348816411
# TOT. GIORNALIERA N. 54 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9621528248358088
# TOT. GIORNALIERA N. 55 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9643659144990125
# TOT. GIORNALIERA N. 56 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9643732975294174
# TOT. GIORNALIERA N. 57 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9646822178292959
# TOT. GIORNALIERA N. 58 -- SPOTNAME N: 60002_0_00 -- MIN. CCF: 0.9633197660739095
# TOT. GIORNALIERA N. 59 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.967707861461017
# TOT. GIORNALIERA N. 60 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9674547618423802
# TOT. GIORNALIERA N. 61 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9714688625289002
# TOT. GIORNALIERA N. 62 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9684967391819569
# TOT. GIORNALIERA N. 63 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9713985553023164
# TOT. GIORNALIERA N. 64 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9700915106749511
# TOT. GIORNALIERA N. 65 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9686583838883496
# TOT. GIORNALIERA N. 66 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9703900752181496
# TOT. GIORNALIERA N. 67 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9638778287648065
# TOT. GIORNALIERA N. 68 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9696826252279974
# TOT. GIORNALIERA N. 69 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.961953966766205
# TOT. GIORNALIERA N. 70 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9610363933991315
# TOT. GIORNALIERA N. 71 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9608043937358768
# TOT. GIORNALIERA N. 72 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9716826766910011
# TOT. GIORNALIERA N. 73 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9702767665428444
# TOT. GIORNALIERA N. 74 -- SPOTNAME N: 60003_0_00 -- MIN. CCF: 0.9699668333506636
# TOT. GIORNALIERA N. 75 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9663560603955837
# TOT. GIORNALIERA N. 76 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9660868212393984
# TOT. GIORNALIERA N. 77 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9652198158826291
# TOT. GIORNALIERA N. 78 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9639174635711675
# TOT. GIORNALIERA N. 79 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9650754000956134
# TOT. GIORNALIERA N. 80 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9644868714344245
# TOT. GIORNALIERA N. 81 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9637440752315991
# TOT. GIORNALIERA N. 82 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9638723181056486
# TOT. GIORNALIERA N. 83 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9654431775541965
# TOT. GIORNALIERA N. 84 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9630960067782153
# TOT. GIORNALIERA N. 85 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9626161130259686
# TOT. GIORNALIERA N. 86 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.964879815604531
# TOT. GIORNALIERA N. 87 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9650491918436475
# TOT. GIORNALIERA N. 88 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9653998557157146
# TOT. GIORNALIERA N. 89 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9647989690945692
# TOT. GIORNALIERA N. 90 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9671374671635895
# TOT. GIORNALIERA N. 91 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9649830456878713
# TOT. GIORNALIERA N. 92 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9616911784741686
# TOT. GIORNALIERA N. 93 -- SPOTNAME N: 60010_0_00 -- MIN. CCF: 0.9554755687923189
# TOT. GIORNALIERA N. 94 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9654125606565878
# TOT. GIORNALIERA N. 95 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.963958288676904
# TOT. GIORNALIERA N. 96 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9640529098084574
# TOT. GIORNALIERA N. 97 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.962755683613381
# TOT. GIORNALIERA N. 98 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9663585420346682
# TOT. GIORNALIERA N. 99 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9658675889489459
# TOT. GIORNALIERA N. 100 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9648526650955873
# TOT. GIORNALIERA N. 101 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.965287632474823
# TOT. GIORNALIERA N. 102 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9646297276030985
# TOT. GIORNALIERA N. 103 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9660177910519545
# TOT. GIORNALIERA N. 104 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9641497383204904
# TOT. GIORNALIERA N. 105 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.966309063395545
# TOT. GIORNALIERA N. 106 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9547232395467035
# TOT. GIORNALIERA N. 107 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9650316153355073
# TOT. GIORNALIERA N. 108 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9634900130862878
# TOT. GIORNALIERA N. 109 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9651479228959993
# TOT. GIORNALIERA N. 110 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9653646871705485
# TOT. GIORNALIERA N. 111 -- SPOTNAME N: 60011_0_00 -- MIN. CCF: 0.9646752646094593
# TOT. GIORNALIERA N. 112 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9606104715449949
# TOT. GIORNALIERA N. 113 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9674051923018004
# TOT. GIORNALIERA N. 114 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9671475081505049
# TOT. GIORNALIERA N. 115 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.966300712433
# TOT. GIORNALIERA N. 116 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9654137526501424
# TOT. GIORNALIERA N. 117 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9665491452243983
# TOT. GIORNALIERA N. 118 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9628765864360734
# TOT. GIORNALIERA N. 119 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9639832487863533
# TOT. GIORNALIERA N. 120 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9664436158984125
# TOT. GIORNALIERA N. 121 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9629747941928881
# TOT. GIORNALIERA N. 122 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9668960779370389
# TOT. GIORNALIERA N. 123 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9664695271243466
# TOT. GIORNALIERA N. 124 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9656729679120943
# TOT. GIORNALIERA N. 125 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9673683108224148
# TOT. GIORNALIERA N. 126 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9637603211648875
# TOT. GIORNALIERA N. 127 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9667800233250563
# TOT. GIORNALIERA N. 128 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9647170712384037
# TOT. GIORNALIERA N. 129 -- SPOTNAME N: 60016_0_00 -- MIN. CCF: 0.9667826268210051
# TOT. GIORNALIERA N. 130 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9667109480236943
# TOT. GIORNALIERA N. 131 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9668933742245872
# TOT. GIORNALIERA N. 132 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9625150655573329
# TOT. GIORNALIERA N. 133 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.964482998631349
# TOT. GIORNALIERA N. 134 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9620562954195302
# TOT. GIORNALIERA N. 135 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9599321580120973
# TOT. GIORNALIERA N. 136 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9634759114832764
# TOT. GIORNALIERA N. 137 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9610921436159153
# TOT. GIORNALIERA N. 138 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9630112054276936
# TOT. GIORNALIERA N. 139 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.964950177065022
# TOT. GIORNALIERA N. 140 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9557896891102494
# TOT. GIORNALIERA N. 141 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9636457314420325
# TOT. GIORNALIERA N. 142 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9648209342464356
# TOT. GIORNALIERA N. 143 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9613218847147428
# TOT. GIORNALIERA N. 144 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.966227243544345
# TOT. GIORNALIERA N. 145 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9636420631158704
# TOT. GIORNALIERA N. 146 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9675532344723022
# TOT. GIORNALIERA N. 147 -- SPOTNAME N: 60017_0_00 -- MIN. CCF: 0.9652688493744919
# TOT. GIORNALIERA N. 148 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9612667943791845
# TOT. GIORNALIERA N. 149 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9652029481124254
# TOT. GIORNALIERA N. 150 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.96418969339096
# TOT. GIORNALIERA N. 151 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9642147290747798
# TOT. GIORNALIERA N. 152 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.960222414572403
# TOT. GIORNALIERA N. 153 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9633670555829852
# TOT. GIORNALIERA N. 154 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9646056099119382
# TOT. GIORNALIERA N. 155 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9595573005120736
# TOT. GIORNALIERA N. 156 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.960855128415578
# TOT. GIORNALIERA N. 157 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9621737634310219
# TOT. GIORNALIERA N. 158 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9627409702122777
# TOT. GIORNALIERA N. 159 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9658761207164618
# TOT. GIORNALIERA N. 160 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9647795031295625
# TOT. GIORNALIERA N. 161 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9642414742895379
# TOT. GIORNALIERA N. 162 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9639114071318859
# TOT. GIORNALIERA N. 163 -- SPOTNAME N: 60020_0_00 -- MIN. CCF: 0.9643206165595157
# TOT. GIORNALIERA N. 164 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9591234486820198
# TOT. GIORNALIERA N. 165 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.954578139872068
# TOT. GIORNALIERA N. 166 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9567482460637953
# TOT. GIORNALIERA N. 167 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9536413516765677
# TOT. GIORNALIERA N. 168 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9553505740719209
# TOT. GIORNALIERA N. 169 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9574142407846576
# TOT. GIORNALIERA N. 170 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9558543758017741
# TOT. GIORNALIERA N. 171 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9488069771891542
# TOT. GIORNALIERA N. 172 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9556491100941895
# TOT. GIORNALIERA N. 173 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9565053746692195
# TOT. GIORNALIERA N. 174 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9558054400264095
# TOT. GIORNALIERA N. 175 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9581465126707266
# TOT. GIORNALIERA N. 176 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9580722172648516
# TOT. GIORNALIERA N. 177 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9568569870532145
# TOT. GIORNALIERA N. 178 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9557010174641963
# TOT. GIORNALIERA N. 179 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.952717473016995
# TOT. GIORNALIERA N. 180 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9569118389986974
# TOT. GIORNALIERA N. 181 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9560698240942426
# TOT. GIORNALIERA N. 182 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9507807903295256
# TOT. GIORNALIERA N. 183 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9539000375095242
# TOT. GIORNALIERA N. 184 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9539452240484816
# TOT. GIORNALIERA N. 185 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9559751139375745
# TOT. GIORNALIERA N. 186 -- SPOTNAME N: 60021_0_00 -- MIN. CCF: 0.9565033221340525
# TOT. GIORNALIERA N. 187 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9572926206460509
# TOT. GIORNALIERA N. 188 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.952089993987118
# TOT. GIORNALIERA N. 189 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9530731578416475
# TOT. GIORNALIERA N. 190 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9506930332875715
# TOT. GIORNALIERA N. 191 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9552168237610597
# TOT. GIORNALIERA N. 192 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9527502150533173
# TOT. GIORNALIERA N. 193 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9603440014527835
# TOT. GIORNALIERA N. 194 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.951646557587511
# TOT. GIORNALIERA N. 195 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9524076434877495
# TOT. GIORNALIERA N. 196 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9507060471626643
# TOT. GIORNALIERA N. 197 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9536210328361199
# TOT. GIORNALIERA N. 198 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.953778504141228
# TOT. GIORNALIERA N. 199 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.949751919341548
# TOT. GIORNALIERA N. 200 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9567097056882047
# TOT. GIORNALIERA N. 201 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9521825754108314
# TOT. GIORNALIERA N. 202 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9553487934600532
# TOT. GIORNALIERA N. 203 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9480947038102588
# TOT. GIORNALIERA N. 204 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9557147652044125
# TOT. GIORNALIERA N. 205 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9497818919929589
# TOT. GIORNALIERA N. 206 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9534507956179478
# TOT. GIORNALIERA N. 207 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.9535209142380315
# TOT. GIORNALIERA N. 208 -- SPOTNAME N: 60022_0_00 -- MIN. CCF: 0.947196627910103
# TOT. GIORNALIERA N. 209 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9580642464405231
# TOT. GIORNALIERA N. 210 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9583468557098047
# TOT. GIORNALIERA N. 211 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9519776866594802
# TOT. GIORNALIERA N. 212 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9652033189550328
# TOT. GIORNALIERA N. 213 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9530303062381164
# TOT. GIORNALIERA N. 214 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9580672236561276
# TOT. GIORNALIERA N. 215 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9589224831165557
# TOT. GIORNALIERA N. 216 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9583860561697968
# TOT. GIORNALIERA N. 217 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9575896252983064
# TOT. GIORNALIERA N. 218 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.956103360395864
# TOT. GIORNALIERA N. 219 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9575881471864289
# TOT. GIORNALIERA N. 220 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9556563216774071
# TOT. GIORNALIERA N. 221 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9547764515248803
# TOT. GIORNALIERA N. 222 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9595025985561896
# TOT. GIORNALIERA N. 223 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9548132709515845
# TOT. GIORNALIERA N. 224 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9567668230140702
# TOT. GIORNALIERA N. 225 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9510347068087213
# TOT. GIORNALIERA N. 226 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9566219671594078
# TOT. GIORNALIERA N. 227 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9508095537080657
# TOT. GIORNALIERA N. 228 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9520231133005647
# TOT. GIORNALIERA N. 229 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9582967460456285
# TOT. GIORNALIERA N. 230 -- SPOTNAME N: 60023_0_00 -- MIN. CCF: 0.9575727749740699
# TOT. GIORNALIERA N. 231 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9368579676452321
# TOT. GIORNALIERA N. 232 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9415139769286578
# TOT. GIORNALIERA N. 233 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9406060029317949
# TOT. GIORNALIERA N. 234 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9477402815251348
# TOT. GIORNALIERA N. 235 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9471075608558035
# TOT. GIORNALIERA N. 236 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9550899201974907
# TOT. GIORNALIERA N. 237 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9403858001658313
# TOT. GIORNALIERA N. 238 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9465527916522999
# TOT. GIORNALIERA N. 239 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9377716352009254
# TOT. GIORNALIERA N. 240 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9487752525568967
# TOT. GIORNALIERA N. 241 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9465774875214766
# TOT. GIORNALIERA N. 242 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9468729768470281
# TOT. GIORNALIERA N. 243 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9420280779492947
# TOT. GIORNALIERA N. 244 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.930970502601831
# TOT. GIORNALIERA N. 245 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9459487068567449
# TOT. GIORNALIERA N. 246 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9450708643342925
# TOT. GIORNALIERA N. 247 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9451446576711598
# TOT. GIORNALIERA N. 248 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.944883566715788
# TOT. GIORNALIERA N. 249 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9411787953171653
# TOT. GIORNALIERA N. 250 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9429679584768206
# TOT. GIORNALIERA N. 251 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9398855559955825
# TOT. GIORNALIERA N. 252 -- SPOTNAME N: 60024_0_00 -- MIN. CCF: 0.9442647431421884
# TOT. GIORNALIERA N. 253 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9623528435086834
# TOT. GIORNALIERA N. 254 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9671640284581328
# TOT. GIORNALIERA N. 255 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9623219341234155
# TOT. GIORNALIERA N. 256 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9627599148609411
# TOT. GIORNALIERA N. 257 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9640190918552313
# TOT. GIORNALIERA N. 258 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9639497640375948
# TOT. GIORNALIERA N. 259 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9604033840458625
# TOT. GIORNALIERA N. 260 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9634143208549598
# TOT. GIORNALIERA N. 261 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9646117131283403
# TOT. GIORNALIERA N. 262 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9644848381317126
# TOT. GIORNALIERA N. 263 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9701746229075626
# TOT. GIORNALIERA N. 264 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9639354284026541
# TOT. GIORNALIERA N. 265 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9649828895504114
# TOT. GIORNALIERA N. 266 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9608384553240509
# TOT. GIORNALIERA N. 267 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9624379517763101
# TOT. GIORNALIERA N. 268 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9650686775929239
# TOT. GIORNALIERA N. 269 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9663058706782645
# TOT. GIORNALIERA N. 270 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9621122199736724
# TOT. GIORNALIERA N. 271 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9631948302573006
# TOT. GIORNALIERA N. 272 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9655549721279975
# TOT. GIORNALIERA N. 273 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9624218801763132
# TOT. GIORNALIERA N. 274 -- SPOTNAME N: 60025_0_00 -- MIN. CCF: 0.9608343532598298
# TOT. GIORNALIERA N. 275 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9656086461997109
# TOT. GIORNALIERA N. 276 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9663355725771183
# TOT. GIORNALIERA N. 277 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9650537605544318
# TOT. GIORNALIERA N. 278 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9651947585573304
# TOT. GIORNALIERA N. 279 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.96582686963043
# TOT. GIORNALIERA N. 280 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9602150065520321
# TOT. GIORNALIERA N. 281 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9644174082786581
# TOT. GIORNALIERA N. 282 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9653674853534896
# TOT. GIORNALIERA N. 283 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.966481700140175
# TOT. GIORNALIERA N. 284 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9614731871977442
# TOT. GIORNALIERA N. 285 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9673339705258446
# TOT. GIORNALIERA N. 286 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.965047698837903
# TOT. GIORNALIERA N. 287 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9600146716636069
# TOT. GIORNALIERA N. 288 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9647801373526966
# TOT. GIORNALIERA N. 289 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9649930616537514
# TOT. GIORNALIERA N. 290 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9661726983294684
# TOT. GIORNALIERA N. 291 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9664024322736272
# TOT. GIORNALIERA N. 292 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9654427455452054
# TOT. GIORNALIERA N. 293 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9619244280987325
# TOT. GIORNALIERA N. 294 -- SPOTNAME N: 60026_0_00 -- MIN. CCF: 0.9606267034798662
# TOT. GIORNALIERA N. 295 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9632920922039666
# TOT. GIORNALIERA N. 296 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9625184468771786
# TOT. GIORNALIERA N. 297 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9629617059537038
# TOT. GIORNALIERA N. 298 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.964868808127531
# TOT. GIORNALIERA N. 299 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9622646677240979
# TOT. GIORNALIERA N. 300 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9636977954921254
# TOT. GIORNALIERA N. 301 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9629936860494022
# TOT. GIORNALIERA N. 302 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9621078184121752
# TOT. GIORNALIERA N. 303 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9632824341328464
# TOT. GIORNALIERA N. 304 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.962853131391578
# TOT. GIORNALIERA N. 305 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.961393234388787
# TOT. GIORNALIERA N. 306 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9651318663613038
# TOT. GIORNALIERA N. 307 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9625262727562807
# TOT. GIORNALIERA N. 308 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9629612642773717
# TOT. GIORNALIERA N. 309 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9641272974177455
# TOT. GIORNALIERA N. 310 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9645618562930598
# TOT. GIORNALIERA N. 311 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9634633696309365
# TOT. GIORNALIERA N. 312 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9631495385417623
# TOT. GIORNALIERA N. 313 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9620161885200547
# TOT. GIORNALIERA N. 314 -- SPOTNAME N: 60027_0_00 -- MIN. CCF: 0.9629617059537038
# TOT. GIORNALIERA N. 315 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9622663018189789
# TOT. GIORNALIERA N. 316 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9658284776087182
# TOT. GIORNALIERA N. 317 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9634639691548894
# TOT. GIORNALIERA N. 318 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.960217130864383
# TOT. GIORNALIERA N. 319 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.963983710901974
# TOT. GIORNALIERA N. 320 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9679813523424116
# TOT. GIORNALIERA N. 321 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9677741320929407
# TOT. GIORNALIERA N. 322 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9561895959808523
# TOT. GIORNALIERA N. 323 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9674047762319622
# TOT. GIORNALIERA N. 324 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.958717876971428
# TOT. GIORNALIERA N. 325 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9679724505129342
# TOT. GIORNALIERA N. 326 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9669418121144664
# TOT. GIORNALIERA N. 327 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9686939762386642
# TOT. GIORNALIERA N. 328 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9616323334315845
# TOT. GIORNALIERA N. 329 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9561895959808523
# TOT. GIORNALIERA N. 330 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9689468287966011
# TOT. GIORNALIERA N. 331 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9641139275479235
# TOT. GIORNALIERA N. 332 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9626460798003337
# TOT. GIORNALIERA N. 333 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.961917574468451
# TOT. GIORNALIERA N. 334 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9679770970960319
# TOT. GIORNALIERA N. 335 -- SPOTNAME N: 60028_0_00 -- MIN. CCF: 0.9622663018189789
# TOT. GIORNALIERA N. 336 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9665214896717299
# TOT. GIORNALIERA N. 337 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9681113100572265
# TOT. GIORNALIERA N. 338 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9662639729481309
# TOT. GIORNALIERA N. 339 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9683311283187005
# TOT. GIORNALIERA N. 340 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9670830594241306
# TOT. GIORNALIERA N. 341 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9675098561407729
# TOT. GIORNALIERA N. 342 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9661240999622338
# TOT. GIORNALIERA N. 343 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9677372159104572
# TOT. GIORNALIERA N. 344 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9693276177914464
# TOT. GIORNALIERA N. 345 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9687484178549076
# TOT. GIORNALIERA N. 346 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9679654577677574
# TOT. GIORNALIERA N. 347 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9676120210699858
# TOT. GIORNALIERA N. 348 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9681623615861219
# TOT. GIORNALIERA N. 349 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9664171744118418
# TOT. GIORNALIERA N. 350 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9666406036351382
# TOT. GIORNALIERA N. 351 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9671139097817946
# TOT. GIORNALIERA N. 352 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9669598443647981
# TOT. GIORNALIERA N. 353 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.968208014670671
# TOT. GIORNALIERA N. 354 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9671265968939503
# TOT. GIORNALIERA N. 355 -- SPOTNAME N: 60029_0_00 -- MIN. CCF: 0.9684233674918837
# TOT. GIORNALIERA N. 356 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.966902657560409
# TOT. GIORNALIERA N. 357 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.968557369805219
# TOT. GIORNALIERA N. 358 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.965198791172264
# TOT. GIORNALIERA N. 359 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9634023966524057
# TOT. GIORNALIERA N. 360 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9666077968247666
# TOT. GIORNALIERA N. 361 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9609525203822717
# TOT. GIORNALIERA N. 362 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9647860913186675
# TOT. GIORNALIERA N. 363 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9660289684206957
# TOT. GIORNALIERA N. 364 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9682438134978213
# TOT. GIORNALIERA N. 365 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9625060045405219
# TOT. GIORNALIERA N. 366 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9676831427872711
# TOT. GIORNALIERA N. 367 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9642340170494886
# TOT. GIORNALIERA N. 368 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9662489169654247
# TOT. GIORNALIERA N. 369 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.963711942173143
# TOT. GIORNALIERA N. 370 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9681085924617651
# TOT. GIORNALIERA N. 371 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9689826035716413
# TOT. GIORNALIERA N. 372 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9612270989980188
# TOT. GIORNALIERA N. 373 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.9650608388069322
# TOT. GIORNALIERA N. 374 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.967394590122883
# TOT. GIORNALIERA N. 375 -- SPOTNAME N: 60030_0_00 -- MIN. CCF: 0.967801996799135
# TOT. GIORNALIERA N. 376 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9659092110278447
# TOT. GIORNALIERA N. 377 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9633198752727933
# TOT. GIORNALIERA N. 378 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9648666817798683
# TOT. GIORNALIERA N. 379 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9641954832729247
# TOT. GIORNALIERA N. 380 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9677269741239583
# TOT. GIORNALIERA N. 381 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9652359799188799
# TOT. GIORNALIERA N. 382 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9632173205869654
# TOT. GIORNALIERA N. 383 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9650225041308435
# TOT. GIORNALIERA N. 384 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9558030270721611
# TOT. GIORNALIERA N. 385 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9631865233334631
# TOT. GIORNALIERA N. 386 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9651451026267241
# TOT. GIORNALIERA N. 387 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9549363502262482
# TOT. GIORNALIERA N. 388 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9659891163783305
# TOT. GIORNALIERA N. 389 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9657997380232811
# TOT. GIORNALIERA N. 390 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9662327011743176
# TOT. GIORNALIERA N. 391 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9650167287808765
# TOT. GIORNALIERA N. 392 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.964578151435177
# TOT. GIORNALIERA N. 393 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9666989579183877
# TOT. GIORNALIERA N. 394 -- SPOTNAME N: 60031_0_00 -- MIN. CCF: 0.9619216474836828
# TOT. GIORNALIERA N. 395 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9658848329876358
# TOT. GIORNALIERA N. 396 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9624571050693472
# TOT. GIORNALIERA N. 397 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9633965062290473
# TOT. GIORNALIERA N. 398 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9538174910375925
# TOT. GIORNALIERA N. 399 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9657803289299262
# TOT. GIORNALIERA N. 400 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9526258296515088
# TOT. GIORNALIERA N. 401 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9621586933296803
# TOT. GIORNALIERA N. 402 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9652862815338066
# TOT. GIORNALIERA N. 403 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9604001074194791
# TOT. GIORNALIERA N. 404 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9656098869822436
# TOT. GIORNALIERA N. 405 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9658147090811908
# TOT. GIORNALIERA N. 406 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9643276246655607
# TOT. GIORNALIERA N. 407 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9631339155391468
# TOT. GIORNALIERA N. 408 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9615061187593482
# TOT. GIORNALIERA N. 409 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9663767653313047
# TOT. GIORNALIERA N. 410 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9627079476581002
# TOT. GIORNALIERA N. 411 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9618572429979666
# TOT. GIORNALIERA N. 412 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9593875401867373
# TOT. GIORNALIERA N. 413 -- SPOTNAME N: 60032_0_00 -- MIN. CCF: 0.9595963316385465
# TOT. GIORNALIERA N. 414 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9653119458381988
# TOT. GIORNALIERA N. 415 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9645772649880784
# TOT. GIORNALIERA N. 416 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9638636173296882
# TOT. GIORNALIERA N. 417 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9641760507371393
# TOT. GIORNALIERA N. 418 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9633493676617142
# TOT. GIORNALIERA N. 419 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9624274533564567
# TOT. GIORNALIERA N. 420 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9619726281853772
# TOT. GIORNALIERA N. 421 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9549692449338348
# TOT. GIORNALIERA N. 422 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9633651563405133
# TOT. GIORNALIERA N. 423 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.964827411153493
# TOT. GIORNALIERA N. 424 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9670061136484907
# TOT. GIORNALIERA N. 425 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9637482121687226
# TOT. GIORNALIERA N. 426 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9637430749863992
# TOT. GIORNALIERA N. 427 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9611923527387609
# TOT. GIORNALIERA N. 428 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9642233522241356
# TOT. GIORNALIERA N. 429 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9642719581673183
# TOT. GIORNALIERA N. 430 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9639274684052596
# TOT. GIORNALIERA N. 431 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9631573446734739
# TOT. GIORNALIERA N. 432 -- SPOTNAME N: 60033_0_00 -- MIN. CCF: 0.9649645535255028
# TOT. GIORNALIERA N. 433 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9718054988792474
# TOT. GIORNALIERA N. 434 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9612582078591899
# TOT. GIORNALIERA N. 435 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9715495356145012
# TOT. GIORNALIERA N. 436 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.971556827616394
# TOT. GIORNALIERA N. 437 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9702708401686843
# TOT. GIORNALIERA N. 438 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9706627640073422
# TOT. GIORNALIERA N. 439 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9709902700395215
# TOT. GIORNALIERA N. 440 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9698230349277208
# TOT. GIORNALIERA N. 441 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9700148583850524
# TOT. GIORNALIERA N. 442 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9702570232948796
# TOT. GIORNALIERA N. 443 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.969426390683679
# TOT. GIORNALIERA N. 444 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9679935643662152
# TOT. GIORNALIERA N. 445 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9691488416443038
# TOT. GIORNALIERA N. 446 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9711680214268273
# TOT. GIORNALIERA N. 447 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9707510247957694
# TOT. GIORNALIERA N. 448 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9709385677480631
# TOT. GIORNALIERA N. 449 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9696045409962761
# TOT. GIORNALIERA N. 450 -- SPOTNAME N: 60042_0_00 -- MIN. CCF: 0.9701062371311184
# TOT. GIORNALIERA N. 451 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9693526415389395
# TOT. GIORNALIERA N. 452 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9695390911374807
# TOT. GIORNALIERA N. 453 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9697436698101276
# TOT. GIORNALIERA N. 454 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9672453938853303
# TOT. GIORNALIERA N. 455 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9680553524820037
# TOT. GIORNALIERA N. 456 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9678787675428747
# TOT. GIORNALIERA N. 457 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9663811565801323
# TOT. GIORNALIERA N. 458 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.966511687788628
# TOT. GIORNALIERA N. 459 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9690508747659935
# TOT. GIORNALIERA N. 460 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.968697945702947
# TOT. GIORNALIERA N. 461 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.966140660216061
# TOT. GIORNALIERA N. 462 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9678692569864333
# TOT. GIORNALIERA N. 463 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9676094944749345
# TOT. GIORNALIERA N. 464 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9698202886652985
# TOT. GIORNALIERA N. 465 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9687767215615081
# TOT. GIORNALIERA N. 466 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.967934966927693
# TOT. GIORNALIERA N. 467 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9687358922221074
# TOT. GIORNALIERA N. 468 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9690195083491837
# TOT. GIORNALIERA N. 469 -- SPOTNAME N: 60043_0_00 -- MIN. CCF: 0.9675134713019564
# TOT. GIORNALIERA N. 470 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9707985612622937
# TOT. GIORNALIERA N. 471 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9698854297747529
# TOT. GIORNALIERA N. 472 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.967038148209586
# TOT. GIORNALIERA N. 473 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9687817978125918
# TOT. GIORNALIERA N. 474 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9721300389747529
# TOT. GIORNALIERA N. 475 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9695307087781649
# TOT. GIORNALIERA N. 476 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.969997388010587
# TOT. GIORNALIERA N. 477 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9708306727458861
# TOT. GIORNALIERA N. 478 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9690502433389179
# TOT. GIORNALIERA N. 479 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9715593745584986
# TOT. GIORNALIERA N. 480 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.969502812753948
# TOT. GIORNALIERA N. 481 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9713136758861977
# TOT. GIORNALIERA N. 482 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9698941374726096
# TOT. GIORNALIERA N. 483 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9699654108057016
# TOT. GIORNALIERA N. 484 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9680122753172721
# TOT. GIORNALIERA N. 485 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9719009291134232
# TOT. GIORNALIERA N. 486 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9692416410390099
# TOT. GIORNALIERA N. 487 -- SPOTNAME N: 60044_0_00 -- MIN. CCF: 0.9692824976593636
# TOT. GIORNALIERA N. 488 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.96803511365832
# TOT. GIORNALIERA N. 489 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9705401540300793
# TOT. GIORNALIERA N. 490 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9712966378418043
# TOT. GIORNALIERA N. 491 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9682389727590236
# TOT. GIORNALIERA N. 492 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9679350912419916
# TOT. GIORNALIERA N. 493 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9681860686838916
# TOT. GIORNALIERA N. 494 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9697180856497697
# TOT. GIORNALIERA N. 495 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9683994440068071
# TOT. GIORNALIERA N. 496 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.971619932120022
# TOT. GIORNALIERA N. 497 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9667577983055221
# TOT. GIORNALIERA N. 498 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9699165900558866
# TOT. GIORNALIERA N. 499 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9686712029180212
# TOT. GIORNALIERA N. 500 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9706260271293657
# TOT. GIORNALIERA N. 501 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9700270473824788
# TOT. GIORNALIERA N. 502 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9673793828742299
# TOT. GIORNALIERA N. 503 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9705476252864503
# TOT. GIORNALIERA N. 504 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9703876081077009
# TOT. GIORNALIERA N. 505 -- SPOTNAME N: 60045_0_00 -- MIN. CCF: 0.9691076313037364
# TOT. GIORNALIERA N. 506 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9700158628473808
# TOT. GIORNALIERA N. 507 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9690947170352698
# TOT. GIORNALIERA N. 508 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9712778506179464
# TOT. GIORNALIERA N. 509 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9694239192922134
# TOT. GIORNALIERA N. 510 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9711173096905209
# TOT. GIORNALIERA N. 511 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9635360026380764
# TOT. GIORNALIERA N. 512 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9608101394897802
# TOT. GIORNALIERA N. 513 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9697033949272834
# TOT. GIORNALIERA N. 514 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9697624504552016
# TOT. GIORNALIERA N. 515 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9606006908671852
# TOT. GIORNALIERA N. 516 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9694529686245309
# TOT. GIORNALIERA N. 517 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.97053032723777
# TOT. GIORNALIERA N. 518 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.969675886608792
# TOT. GIORNALIERA N. 519 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9709314815849956
# TOT. GIORNALIERA N. 520 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9680460341690857
# TOT. GIORNALIERA N. 521 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9695456754643977
# TOT. GIORNALIERA N. 522 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9711469542504405
# TOT. GIORNALIERA N. 523 -- SPOTNAME N: 60046_0_00 -- MIN. CCF: 0.9700051965812198
# TOT. GIORNALIERA N. 524 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9695579496431281
# TOT. GIORNALIERA N. 525 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9716048343863328
# TOT. GIORNALIERA N. 526 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9693943841154034
# TOT. GIORNALIERA N. 527 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9680773770979734
# TOT. GIORNALIERA N. 528 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9708131551012275
# TOT. GIORNALIERA N. 529 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9704786896315993
# TOT. GIORNALIERA N. 530 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9659473223092101
# TOT. GIORNALIERA N. 531 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.969263882230505
# TOT. GIORNALIERA N. 532 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9705898933506355
# TOT. GIORNALIERA N. 533 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9709975628087308
# TOT. GIORNALIERA N. 534 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9694893297514393
# TOT. GIORNALIERA N. 535 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9683837344873829
# TOT. GIORNALIERA N. 536 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.970241759674828
# TOT. GIORNALIERA N. 537 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9700406452674525
# TOT. GIORNALIERA N. 538 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9694568925367062
# TOT. GIORNALIERA N. 539 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9703279070500012
# TOT. GIORNALIERA N. 540 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9697899863461997
# TOT. GIORNALIERA N. 541 -- SPOTNAME N: 60047_0_00 -- MIN. CCF: 0.9682275171742855
# TOT. GIORNALIERA N. 542 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9696500864930959
# TOT. GIORNALIERA N. 543 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9690934408461158
# TOT. GIORNALIERA N. 544 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9691985977684484
# TOT. GIORNALIERA N. 545 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9688080617460217
# TOT. GIORNALIERA N. 546 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9701364893231368
# TOT. GIORNALIERA N. 547 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9701188382747357
# TOT. GIORNALIERA N. 548 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9633445120576773
# TOT. GIORNALIERA N. 549 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9708834612556434
# TOT. GIORNALIERA N. 550 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9673147572971191
# TOT. GIORNALIERA N. 551 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9683673391097047
# TOT. GIORNALIERA N. 552 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9698752378900277
# TOT. GIORNALIERA N. 553 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9713642279211578
# TOT. GIORNALIERA N. 554 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9703581669846529
# TOT. GIORNALIERA N. 555 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9700728587980045
# TOT. GIORNALIERA N. 556 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9686128551522587
# TOT. GIORNALIERA N. 557 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9686831549503778
# TOT. GIORNALIERA N. 558 -- SPOTNAME N: 60048_0_00 -- MIN. CCF: 0.9695129280658488
# TOT. GIORNALIERA N. 559 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9612995149349766
# TOT. GIORNALIERA N. 560 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9590692217121838
# TOT. GIORNALIERA N. 561 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9650918919196404
# TOT. GIORNALIERA N. 562 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9625341634140574
# TOT. GIORNALIERA N. 563 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9606737128294071
# TOT. GIORNALIERA N. 564 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9431946771030928
# TOT. GIORNALIERA N. 565 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9629620222136147
# TOT. GIORNALIERA N. 566 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9643336727083468
# TOT. GIORNALIERA N. 567 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.964365008457838
# TOT. GIORNALIERA N. 568 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.961123273621894
# TOT. GIORNALIERA N. 569 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9455860886826671
# TOT. GIORNALIERA N. 570 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9632222650249526
# TOT. GIORNALIERA N. 571 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9648417486872426
# TOT. GIORNALIERA N. 572 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9634997366299854
# TOT. GIORNALIERA N. 573 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9624161028266321
# TOT. GIORNALIERA N. 574 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9641784183504907
# TOT. GIORNALIERA N. 575 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9649003199587421
# TOT. GIORNALIERA N. 576 -- SPOTNAME N: 60049_0_00 -- MIN. CCF: 0.9642743891078678
# TOT. GIORNALIERA N. 577 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9703553154404502
# TOT. GIORNALIERA N. 578 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9683776879855128
# TOT. GIORNALIERA N. 579 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9684281303431096
# TOT. GIORNALIERA N. 580 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9705644163838806
# TOT. GIORNALIERA N. 581 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9710496879252124
# TOT. GIORNALIERA N. 582 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9663898144812674
# TOT. GIORNALIERA N. 583 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.971951726736953
# TOT. GIORNALIERA N. 584 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9627646412685243
# TOT. GIORNALIERA N. 585 -- SPOTNAME N: 60050_0_00 -- MIN. CCF: 0.9696467801586708
# ...
# TOT. GIORNALIERA N. 1233 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9730900721931044
# TOT. GIORNALIERA N. 1234 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9732386939760426
# TOT. GIORNALIERA N. 1235 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9689202147443131
# TOT. GIORNALIERA N. 1236 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9726711938017996
# TOT. GIORNALIERA N. 1237 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9731255936186332
# TOT. GIORNALIERA N. 1238 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9721654134555358
# TOT. GIORNALIERA N. 1239 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9728417089170214
# TOT. GIORNALIERA N. 1240 -- SPOTNAME N: 60161_0_00 -- MIN. CCF: 0.9725083765916046
# TOT. GIORNALIERA N. 1241 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9661623874485471
# TOT. GIORNALIERA N. 1242 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9692088813256661
# TOT. GIORNALIERA N. 1243 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.969467620954584
# TOT. GIORNALIERA N. 1244 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9695031278362536
# TOT. GIORNALIERA N. 1245 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.968365729684902
# TOT. GIORNALIERA N. 1246 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9690311831652887
# TOT. GIORNALIERA N. 1247 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9706850048321609
# TOT. GIORNALIERA N. 1248 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.968334697497956
# TOT. GIORNALIERA N. 1249 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.968744478623335
# TOT. GIORNALIERA N. 1250 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9694029169244341
# TOT. GIORNALIERA N. 1251 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.96867790244356
# TOT. GIORNALIERA N. 1252 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9695094353018606
# TOT. GIORNALIERA N. 1253 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9698056299494316
# TOT. GIORNALIERA N. 1254 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9697181363132953
# TOT. GIORNALIERA N. 1255 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9675114623067956
# TOT. GIORNALIERA N. 1256 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9695726081355851
# TOT. GIORNALIERA N. 1257 -- SPOTNAME N: 60162_0_00 -- MIN. CCF: 0.9685288115852437
# TOT. GIORNALIERA N. 1258 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9726360982842616
# TOT. GIORNALIERA N. 1259 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.972323777929196
# TOT. GIORNALIERA N. 1260 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9727198049929866
# TOT. GIORNALIERA N. 1261 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9653235868373845
# TOT. GIORNALIERA N. 1262 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9731104777643056
# TOT. GIORNALIERA N. 1263 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9726623019711295
# TOT. GIORNALIERA N. 1264 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9721055389133546
# TOT. GIORNALIERA N. 1265 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9734647086791328
# TOT. GIORNALIERA N. 1266 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9731177124180926
# TOT. GIORNALIERA N. 1267 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.968875305427638
# TOT. GIORNALIERA N. 1268 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9711212321596007
# TOT. GIORNALIERA N. 1269 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9659447175667533
# TOT. GIORNALIERA N. 1270 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9707257329862387
# TOT. GIORNALIERA N. 1271 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9717852427654634
# TOT. GIORNALIERA N. 1272 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9708845136410528
# TOT. GIORNALIERA N. 1273 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9707981408471233
# TOT. GIORNALIERA N. 1274 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.9731448293242804
# TOT. GIORNALIERA N. 1275 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.973262148773329
# TOT. GIORNALIERA N. 1276 -- SPOTNAME N: 60163_0_00 -- MIN. CCF: 0.970269904385679
# TOT. GIORNALIERA N. 1277 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9565550574108338
# TOT. GIORNALIERA N. 1278 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9562628866666321
# TOT. GIORNALIERA N. 1279 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9527690709884161
# TOT. GIORNALIERA N. 1280 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9519244721356347
# TOT. GIORNALIERA N. 1281 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9546610473502938
# TOT. GIORNALIERA N. 1282 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9545001602007949
# TOT. GIORNALIERA N. 1283 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9573552576325307
# TOT. GIORNALIERA N. 1284 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9549498972817525
# TOT. GIORNALIERA N. 1285 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9555449926988911
# TOT. GIORNALIERA N. 1286 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9526038130987511
# TOT. GIORNALIERA N. 1287 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9527524555145976
# TOT. GIORNALIERA N. 1288 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9541850463013013
# TOT. GIORNALIERA N. 1289 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9514665246283293
# TOT. GIORNALIERA N. 1290 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9566337895862295
# TOT. GIORNALIERA N. 1291 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9519491722871726
# TOT. GIORNALIERA N. 1292 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9574337124800488
# TOT. GIORNALIERA N. 1293 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9539174313642943
# TOT. GIORNALIERA N. 1294 -- SPOTNAME N: 60166_0_00 -- MIN. CCF: 0.9525606680968582
# TOT. GIORNALIERA N. 1295 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.960819529920371
# TOT. GIORNALIERA N. 1296 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9660615039898707
# TOT. GIORNALIERA N. 1297 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9610155747936042
# TOT. GIORNALIERA N. 1298 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9590974696512126
# TOT. GIORNALIERA N. 1299 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9604359811703898
# TOT. GIORNALIERA N. 1300 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9588340924452122
# TOT. GIORNALIERA N. 1301 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9602218856363468
# TOT. GIORNALIERA N. 1302 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9599951897302909
# TOT. GIORNALIERA N. 1303 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9585658075995125
# TOT. GIORNALIERA N. 1304 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9587909331924048
# TOT. GIORNALIERA N. 1305 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9580080947420426
# TOT. GIORNALIERA N. 1306 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9591819606720424
# TOT. GIORNALIERA N. 1307 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9600179150083382
# TOT. GIORNALIERA N. 1308 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9613124090617127
# TOT. GIORNALIERA N. 1309 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9614882225349083
# TOT. GIORNALIERA N. 1310 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9612658644957734
# TOT. GIORNALIERA N. 1311 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9604250948928038
# TOT. GIORNALIERA N. 1312 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9584676604740839
# TOT. GIORNALIERA N. 1313 -- SPOTNAME N: 60167_0_00 -- MIN. CCF: 0.9591103386327793
# TOT. GIORNALIERA N. 1314 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9625205816485085
# TOT. GIORNALIERA N. 1315 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9626088761327989
# TOT. GIORNALIERA N. 1316 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9585999130385394
# TOT. GIORNALIERA N. 1317 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.962394014206476
# TOT. GIORNALIERA N. 1318 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9586617527671297
# TOT. GIORNALIERA N. 1319 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9601669937173455
# TOT. GIORNALIERA N. 1320 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9616160635149723
# TOT. GIORNALIERA N. 1321 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9598634991981116
# TOT. GIORNALIERA N. 1322 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9596357396338061
# TOT. GIORNALIERA N. 1323 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9626516484456629
# TOT. GIORNALIERA N. 1324 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9630973858368682
# TOT. GIORNALIERA N. 1325 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9605199678020306
# TOT. GIORNALIERA N. 1326 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9599479533323153
# TOT. GIORNALIERA N. 1327 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9616463023114057
# TOT. GIORNALIERA N. 1328 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9642754879523666
# TOT. GIORNALIERA N. 1329 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9609379404526066
# TOT. GIORNALIERA N. 1330 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9623189711620598
# TOT. GIORNALIERA N. 1331 -- SPOTNAME N: 60168_0_00 -- MIN. CCF: 0.9582677181959294
# TOT. GIORNALIERA N. 1332 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9637213052442849
# TOT. GIORNALIERA N. 1333 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9626337497156365
# TOT. GIORNALIERA N. 1334 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9645828764795172
# TOT. GIORNALIERA N. 1335 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9609252754107434
# TOT. GIORNALIERA N. 1336 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9591472045094158
# TOT. GIORNALIERA N. 1337 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9583019336163595
# TOT. GIORNALIERA N. 1338 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9643009831653452
# TOT. GIORNALIERA N. 1339 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9627461706084441
# TOT. GIORNALIERA N. 1340 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9645861127341655
# TOT. GIORNALIERA N. 1341 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.961990632356832
# TOT. GIORNALIERA N. 1342 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9624388454528697
# TOT. GIORNALIERA N. 1343 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9643648872436407
# TOT. GIORNALIERA N. 1344 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9632197710123805
# TOT. GIORNALIERA N. 1345 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.966671332197986
# TOT. GIORNALIERA N. 1346 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.961685767193783
# TOT. GIORNALIERA N. 1347 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9638783178782133
# TOT. GIORNALIERA N. 1348 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9611199824522026
# TOT. GIORNALIERA N. 1349 -- SPOTNAME N: 60169_0_00 -- MIN. CCF: 0.9618994489128124
# TOT. GIORNALIERA N. 1350 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9740931224462138
# TOT. GIORNALIERA N. 1351 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9738591173756136
# TOT. GIORNALIERA N. 1352 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9757143271352402
# TOT. GIORNALIERA N. 1353 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9753205212924825
# TOT. GIORNALIERA N. 1354 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9755234359450542
# TOT. GIORNALIERA N. 1355 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9753591378401852
# TOT. GIORNALIERA N. 1356 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9748677776171557
# TOT. GIORNALIERA N. 1357 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9759786633716658
# TOT. GIORNALIERA N. 1358 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.972966113507751
# TOT. GIORNALIERA N. 1359 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9748532119728951
# TOT. GIORNALIERA N. 1360 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9748992286304966
# TOT. GIORNALIERA N. 1361 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.973640108506671
# TOT. GIORNALIERA N. 1362 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9745071409844046
# TOT. GIORNALIERA N. 1363 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.973769083820712
# TOT. GIORNALIERA N. 1364 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9754810660033031
# TOT. GIORNALIERA N. 1365 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9747313015030147
# TOT. GIORNALIERA N. 1366 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9736740573635642
# TOT. GIORNALIERA N. 1367 -- SPOTNAME N: 60180_0_00 -- MIN. CCF: 0.9746600840520159
# TOT. GIORNALIERA N. 1368 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9733879129661813
# TOT. GIORNALIERA N. 1369 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9750305785063603
# TOT. GIORNALIERA N. 1370 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9739939658513534
# TOT. GIORNALIERA N. 1371 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9749144155927325
# TOT. GIORNALIERA N. 1372 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9730118051926115
# TOT. GIORNALIERA N. 1373 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9762131279764618
# TOT. GIORNALIERA N. 1374 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.974695556313566
# TOT. GIORNALIERA N. 1375 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9748122799994289
# TOT. GIORNALIERA N. 1376 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9733306843646796
# TOT. GIORNALIERA N. 1377 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9739300744280975
# TOT. GIORNALIERA N. 1378 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9742748761935248
# TOT. GIORNALIERA N. 1379 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9735669153936188
# TOT. GIORNALIERA N. 1380 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9740634199810873
# TOT. GIORNALIERA N. 1381 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9736453075993952
# TOT. GIORNALIERA N. 1382 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9747232367148064
# TOT. GIORNALIERA N. 1383 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9753043922957518
# TOT. GIORNALIERA N. 1384 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9735893485694206
# TOT. GIORNALIERA N. 1385 -- SPOTNAME N: 60181_0_00 -- MIN. CCF: 0.9734983596923092
# TOT. GIORNALIERA N. 1386 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9782223710383354
# TOT. GIORNALIERA N. 1387 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9773277024765533
# TOT. GIORNALIERA N. 1388 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9774949293473353
# TOT. GIORNALIERA N. 1389 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9770790610847785
# TOT. GIORNALIERA N. 1390 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9789611585478689
# TOT. GIORNALIERA N. 1391 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9782450485743176
# TOT. GIORNALIERA N. 1392 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.977919484265529
# TOT. GIORNALIERA N. 1393 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9775435886208684
# TOT. GIORNALIERA N. 1394 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9798307181858772
# TOT. GIORNALIERA N. 1395 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9783016149281764
# TOT. GIORNALIERA N. 1396 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.976116454449448
# TOT. GIORNALIERA N. 1397 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.975747810351527
# TOT. GIORNALIERA N. 1398 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9778943614310132
# TOT. GIORNALIERA N. 1399 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9772332657657878
# TOT. GIORNALIERA N. 1400 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.97671764386601
# TOT. GIORNALIERA N. 1401 -- SPOTNAME N: 60184_0_00 -- MIN. CCF: 0.9782234187406789
# TOT. GIORNALIERA N. 1402 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9749309158420376
# TOT. GIORNALIERA N. 1403 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9737249377191962
# TOT. GIORNALIERA N. 1404 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.973548439529456
# TOT. GIORNALIERA N. 1405 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9750342491681592
# TOT. GIORNALIERA N. 1406 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.973143446595371
# TOT. GIORNALIERA N. 1407 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9732435957353186
# TOT. GIORNALIERA N. 1408 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9739067100721154
# TOT. GIORNALIERA N. 1409 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9734705979708103
# TOT. GIORNALIERA N. 1410 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9736488995855745
# TOT. GIORNALIERA N. 1411 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9750990753444984
# TOT. GIORNALIERA N. 1412 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.973291691584978
# TOT. GIORNALIERA N. 1413 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9727758095206596
# TOT. GIORNALIERA N. 1414 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9747607653357354
# TOT. GIORNALIERA N. 1415 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9738140776796008
# TOT. GIORNALIERA N. 1416 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9742434444290178
# TOT. GIORNALIERA N. 1417 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9734014261874389
# TOT. GIORNALIERA N. 1418 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9737242451304342
# TOT. GIORNALIERA N. 1419 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9730735356667665
# TOT. GIORNALIERA N. 1420 -- SPOTNAME N: 60185_0_00 -- MIN. CCF: 0.9745125145512971
# TOT. GIORNALIERA N. 1421 -- SPOTNAME N: 9999_9_99 -- MIN. CCF: 0.7788678188259706
# TOT. GIORNALIERA N. 1422 -- SPOTNAME N: 9999_9_99 -- MIN. CCF: 0.7791552674129746
# TOT. GIORNALIERA N. 1423 -- SPOTNAME N: 9999_9_99 -- MIN. CCF: 0.7717435815388377
# TOT. GIORNALIERA N. 1424 -- SPOTNAME N: 9999_9_99 -- MIN. CCF: 0.7779309540906189
# TOT. GIORNALIERA N. 1425 -- SPOTNAME N: 9999_9_99 -- MIN. CCF: 0.7761835604336674

# %%
count_len_diff = 0
# verifico che len currentcurve sia sempre uguale a len voltagecurve
for index, row in tqdm(dataset[~dataset.VoltageCurve.isna()].iterrows(), total=dataset[~dataset.VoltageCurve.isna()].shape[0]):
    l_current = len(row.CurrentCurve)
    l_voltage = len(row.VoltageCurve)
    if l_current != l_voltage:
        print(
            f"Index: {index} --- Len. CurrentCurve: {l_current} --- Len. VoltageCurve: {l_voltage}")
        count_len_diff += 1

# il risultato è 0, procediamo con l'unrolling delle liste
count_len_diff
# Out:
# 100%|██████████████████████████████████████████████████████████████| 142204/142204 [02:28<00:00, 960.46it/s]
# 0

# %%
# Notiamo che punti di saldatura diversi hanno numeri di saldatura differenti nello stesso istante

test_data = dataset[~dataset.VoltageCurve.isna()]
# usiamo il numero di misurazioni presenti nella prima riga del dataset come termine di comparazione
first_length = len(test_data.iloc[1, 2])
# verifico che len currentcurve sia sempre uguale a len voltagecurve
for index, row in tqdm(test_data.iterrows(), total=test_data.shape[0]):
    l_current = len(row['CurrentCurve'])
    if first_length != l_current:
        print(test_data.iloc[1])
        print(row)
        print("\nLenghts diverge!")
        break
# Out:
#   0%|                                                                            | 0/142204 [00:00<?, ?it/s]
# TimeStamp                                     2019-09-17 17:33:48
# spotName                                               60075_0_00
# CurrentCurve    [322, 2099, 3940, 5296, 6362, 7169, 7589, 7750...
# VoltageCurve    [135, 749, 1256, 1534, 1698, 1777, 1748, 1648,...
# Name: 75852, dtype: object
# TimeStamp                                     2019-09-17 17:33:48
# spotName                                               60061_0_00
# CurrentCurve    [312, 2067, 3862, 5267, 6398, 7217, 7959, 8700...
# VoltageCurve    [134, 756, 1292, 1623, 1812, 1876, 1946, 2010,...
# Name: 0, dtype: object
#
# Lenghts diverge!

# %%
# numero totale di sensori
len(dataset.spotName.unique())
# Out:
# 77

# %%
# feature engineering
dataset['Date'] = dataset.TimeStamp.dt.date
dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset['TimeStamp'] = dataset['TimeStamp'].dt.time
dataset.rename(columns={'TimeStamp': 'Time'}, inplace=True)
dataset['n_week'] = dataset['Date'].dt.week
dataset = dataset[['spotName', 'Date',
                   'Time', 'n_week', 'CurrentCurve', 'VoltageCurve']]
dataset
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9732\4114651777.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   dataset['n_week'] = dataset['Date'].dt.week
#           spotName       Date      Time  n_week  \
# 0       60061_0_00 2019-09-17  17:33:48      38
# 75852   60075_0_00 2019-09-17  17:33:48      38
# 75853   60141_0_00 2019-09-17  17:33:48      38
# 75854   60163_0_00 2019-09-17  17:33:48      38
# 75855   60161_0_00 2019-09-17  17:33:48      38
# ...            ...        ...       ...     ...
# 222862  60021_0_00 2020-05-28  15:00:04      22
# 222864  60025_0_00 2020-05-28  15:00:17      22
# 222865  60027_0_00 2020-05-28  15:00:17      22
# 222863  60023_0_00 2020-05-28  15:00:17      22
# 222866   9999_9_99 2020-05-28  15:00:44      22
#
#                                              CurrentCurve  \
# 0       [312, 2067, 3862, 5267, 6398, 7217, 7959, 8700...
# 75852   [322, 2099, 3940, 5296, 6362, 7169, 7589, 7750...
# 75853   [214, 1995, 3836, 5125, 6107, 6813, 7182, 7427...
# 75854   [323, 2137, 4047, 5472, 6475, 7090, 7544, 7803...
# 75855   [327, 2161, 4126, 5468, 6483, 7237, 7662, 7793...
# ...                                                   ...
# 222862  [317, 2095, 3809, 4984, 5714, 6222, 6698, 7110...
# 222864  [344, 2225, 4011, 5234, 6017, 6613, 7051, 7365...
# 222865  [303, 2034, 3644, 4767, 5526, 6103, 6437, 6680...
# 222863  [317, 2065, 3781, 4926, 5688, 6229, 6801, 7118...
# 222866  [339, 2926, 5598, 7380, 8567, 9585, 10349, 105...
#
#                                              VoltageCurve
# 0       [134, 756, 1292, 1623, 1812, 1876, 1946, 2010,...
# 75852   [135, 749, 1256, 1534, 1698, 1777, 1748, 1648,...
# 75853   [95, 696, 1217, 1495, 1686, 1759, 1723, 1686, ...
# 75854   [139, 767, 1298, 1598, 1745, 1766, 1779, 1724,...
# 75855   [135, 763, 1263, 1534, 1677, 1748, 1705, 1627,...
# ...                                                   ...
# 222862  [138, 777, 1332, 1675, 1888, 2008, 2100, 2193,...
# 222864  [134, 763, 1284, 1602, 1779, 1863, 1946, 1972,...
# 222865  [136, 744, 1264, 1600, 1784, 1904, 1944, 1960,...
# 222863  [139, 769, 1303, 1652, 1853, 1976, 2107, 2142,...
# 222866  [125, 906, 1533, 1798, 1857, 1879, 1828, 1644,...
#
# [142204 rows x 6 columns]

# %%
dataset.dtypes
# Out:
# spotName                object
# Date            datetime64[ns]
# Time                    object
# n_week                   int64
# CurrentCurve            object
# VoltageCurve            object
# dtype: object

# %% [markdown]
# ## Quanti giorni ci mancano?

# %%
# abbiamo dal 17-09-2019 al 28-05-2020
dataset.Date.describe()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9732\1119642758.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dataset.Date.describe()
# count                  142204
# unique                     59
# top       2020-01-15 00:00:00
# freq                     5515
# first     2019-09-17 00:00:00
# last      2020-05-28 00:00:00
# Name: Date, dtype: object

# %%
# I diversi spotname sembrano avere la stessa quantità di giorni mancanti
all_days_idx = pd.date_range(start='2019-09-17', end='2020-05-28', freq='1D')
for spotname in dataset.spotName.unique():
    temp_spot = dataset[(dataset.spotName == spotname)
                        ][['Date', 'CurrentCurve']]
    # droppo giorni di cui so già di avere almeno una misurazione
    temp_spot.drop_duplicates(subset=['Date'], inplace=True)
    temp_spot.set_index(temp_spot.Date, inplace=True)
    # inserisco nuovi giorni inserendo Nan per i giorni in cui non ho misurazioni
    temp_spot = temp_spot.reindex(all_days_idx)
    grouped = temp_spot.groupby([temp_spot.index.year, temp_spot.index.month]).agg(
        {'CurrentCurve': lambda x: x.isnull().sum()})
    grouped.plot(kind='bar', fontsize=12, figsize=(10, 10), rot=0,
                 title=f"Spotname: {spotname} -- Numero di giorni mancanti per anno e mese",
                 xlabel="Anno e mese",
                 ylabel="# Giorni non disponibili")
# Out:
# C:\Users\danie\AppData\Local\pypoetry\Cache\virtualenvs\industry-lab-JWw7CphW-py3.9\lib\site-packages\pandas\plotting\_matplotlib\core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
# quante misurazioni x giorno? OTTOBRE MANCA
count_day_misuration = dataset.groupby(['Date'])[
    'CurrentCurve'].count().reset_index()

count_day_misuration.set_index('Date')['CurrentCurve'].plot(kind='bar',
                                                            figsize=(20, 10), fontsize=20, ylabel='Numero di misurazioni', xlabel='Giorno', title='Misurazioni per giorno')
# Out:
# <AxesSubplot:title={'center':'Misurazioni per giorno'}, xlabel='Giorno', ylabel='Numero di misurazioni'>

# %% [markdown]
# # Test set

# %% [markdown]
# Utilizziamo un campione preso con campionamento stratificato e lo utilizziamo successivamente per i test. Le righe al suo interno verranno tolte dal dataset che sarà utilizzato per il fit dei modelli.

# %%
print(dataset.shape)
dataset.drop(sample.index, inplace=True)
print(dataset.shape)
# Out:
# (142204, 6)
# (140778, 6)
# C:\Users\danie\AppData\Local\Temp\ipykernel_9732\4117220153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(sample.index, inplace=True)

# %%
print(sample.shape)
sample.to_pickle('../data/inference/unseen_data.pkl')
# Out:
# (1426, 4)

# %% [markdown]
# # Salvataggio dataset dopo feature engineering

# %% [markdown]
# Dalle analisi di cui sopra, si è notato che i dati mancanti sono molti e si è considerata la loro eventuale imputazione un'operazione che potenzialmente avrebbe potuto aumentare il bias dei futuri modelli a causa dell'inserimento di dati artificiali.<br/>
# La colonna VoltageCurve viene eliminata in quanto dipendente linearmente dalla colonna CurrentCurve.

# %%
dataset.drop(columns=['VoltageCurve'], inplace= True)
dataset.to_pickle('../data/prepared/prepared_dataset.pkl')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9732\3450275834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(columns=['VoltageCurve'], inplace= True)
